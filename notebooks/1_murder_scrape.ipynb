# %% [markdown]
# # Scraping murder data
#
# #### Author: Lydia Kim
# #### Description: Scrapes murder totals, estimates, rates by MSA for 2006-2016 from the FBI website
# #### Output: murder_data.csv

# %%
import numpy as np
import scipy as sp
import pandas as pd
import time
import requests 
from bs4 import BeautifulSoup 
import json
requests.packages.urllib3.disable_warnings()

# %%
def getHTML(the_year, url):
    link = url.format(the_year, the_year)
    print(the_year)
    
    #Get html
    req = requests.get(link, timeout=20, verify=False)
    time.sleep(2)
    page = req.text
    
    yearstext[the_year] = page

# %%
yearstext = dict()
range1 = lambda start, end: range(start, end+1)

for r in range(2006, 2010):
    url = "https://www2.fbi.gov/ucr/cius{}/data/table_06.html".format(r)
    print(r)
    
    #Get html
    req = requests.get(url, timeout=20, verify=False)
    time.sleep(2)
    page = req.text
    
    yearstext[r] = page
    
for r in range(2010, 2012):
    getHTML(r,"https://ucr.fbi.gov/crime-in-the-u.s/{}/crime-in-the-u.s.-{}/tables/table-6")
    
for r in range(2012, 2014):
    getHTML(r,"https://ucr.fbi.gov/crime-in-the-u.s/{}/crime-in-the-u.s.-{}/tables/6tabledatadecpdf")
    
for r in range(2014, 2016):
    getHTML(r,"https://ucr.fbi.gov/crime-in-the-u.s/{}/crime-in-the-u.s.-{}/tables/table-6")

getHTML(2016, "https://ucr.fbi.gov/crime-in-the-u.s/{}/crime-in-the-u.s.-{}/tables/table-4")
# Out:
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016

# %%
def parse_year(the_year):
    soup = BeautifulSoup(yearstext.get(the_year,{}), 'html.parser')
    
    #Extract table
    tables = soup.find_all("table", attrs={"class":"data"})
    table = tables[0]
    rows = table.find_all("tr")[1:]
    
    #Extract singles
    dataset, newdata = [], []

    for no, tr in enumerate(rows):
        for th_no, data in enumerate(tr.find_all('th')):
            if data.has_attr("rowspan"):
                if int(data["rowspan"])>2:
                    MSA = data.get_text().split('M.S.A.', 1)[0].replace('\n','')
                    spanrows = int(data["rowspan"])
                    start = no+1
                    end = (no + spanrows)-1
                    obs = {'MSA': MSA}

                    for r in range1(start, end):
                        cells = rows[r].findAll(["th", "td"])
                        varname = cells[0].get_text().replace('\n','')
                        val = cells[3].get_text().replace('\n','')

                        entry = {'varname': varname, 'values': val}
                        vlist = list(entry.values())
                        name = vlist[0]
                        obs[name] = vlist[1]

                    dataset.append(obs)

            else:
                pass
            
    for x in dataset:
        try:
            estimated = x['Estimated total']
        except KeyError:
            estimated = x['Total area actually reporting']
        try:
            rate = x['Rate per 100,000 inhabitants']
        except KeyError:
            rate = 'NaN'
        try:
            total = x['Total area actually reporting']
        except KeyError:
            total = 'NaN'
            
        tempdict = {'MSA': x['MSA'], 'Total': total, 'Rate': rate, 'Estimated': estimated, 'Year': the_year}
        newdata.append(tempdict)
            
                
    return newdata

# %%
yearinfo = dict()
for r in range(2006, 2017):
    info = parse_year(r)
    yearinfo[r] = info

# %%
fd = open("data/yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %%
with open("data/yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %%
frame = []

for key in yearinfo:
    dftemp = pd.DataFrame.from_dict(yearinfo[key], orient='columns')
    frame.append(dftemp)
    
dftemp2 = pd.concat(frame, ignore_index=True)
df = dftemp2.sort_values(['MSA', 'Year'])
df = df.reset_index(drop=True)
df = df[['MSA', 'Year', 'Total', 'Estimated', 'Rate']]
df
# Out:
#                                                 MSA  Year Total Estimated  \
# 0                                      Abilene, TX   2006     6         6
# 1                                      Abilene, TX   2007    10        10
# 2                                      Abilene, TX   2008     7         7
# 3                                      Abilene, TX   2009     7         7
# 4                                      Abilene, TX   2010     5         5
# 5                                      Abilene, TX   2011     5         5
# 6                                      Abilene, TX   2012     3         3
# 7                                      Abilene, TX   2013     1         1
# 8                                      Abilene, TX   2014    10        10
# 9                                      Abilene, TX   2015     9         9
# 10                                     Abilene, TX   2016    11        11
# 11                  Aguadilla-Isabela, Puerto Rico   2012    31        31
# 12                  Aguadilla-Isabela, Puerto Rico   2013    36        36
# 13                  Aguadilla-Isabela, Puerto Rico   2014    19        19
# 14                  Aguadilla-Isabela, Puerto Rico   2015    15        15
# 15                  Aguadilla-Isabela, Puerto Rico   2016    22        22
# 16    Aguadilla-Isabela-San Sebastian, Puerto Rico   2006     8         8
# 17    Aguadilla-Isabela-San Sebastian, Puerto Rico   2007    13        13
# 18    Aguadilla-Isabela-San Sebastian, Puerto Rico   2008    21        21
# 19    Aguadilla-Isabela-San Sebastian, Puerto Rico   2009    13        13
# 20    Aguadilla-Isabela-San Sebastian, Puerto Rico   2011    30        30
# 21                                       Akron, OH   2007    23        25
# 22                                       Akron, OH   2008    23        24
# 23                                       Akron, OH   2009    27        28
# 24                                       Akron, OH   2010    26        26
# 25                                       Akron, OH   2011    32        33
# 26                                       Akron, OH   2012    26        27
# 27                                       Akron, OH   2013    35        36
# 28                                       Akron, OH   2014    33        34
# 29                                       Akron, OH   2015    35        36
# ...                                             ...   ...   ...       ...
# 4084                              York-Hanover, PA   2013    19        19
# 4085                              York-Hanover, PA   2014    14        14
# 4086                              York-Hanover, PA   2015    19        19
# 4087                              York-Hanover, PA   2016    19        19
# 4088             Youngstown-Warren-Boardman, OH-PA   2008    41        41
# 4089             Youngstown-Warren-Boardman, OH-PA   2009    32        32
# 4090             Youngstown-Warren-Boardman, OH-PA   2010    33        33
# 4091             Youngstown-Warren-Boardman, OH-PA   2012    32        32
# 4092             Youngstown-Warren-Boardman, OH-PA   2014    24        24
# 4093                                 Yuba City, CA   2006     7         7
# 4094                                 Yuba City, CA   2007     2         2
# 4095                                 Yuba City, CA   2008    10        10
# 4096                                 Yuba City, CA   2009     4         4
# 4097                                 Yuba City, CA   2010     7         7
# 4098                                 Yuba City, CA   2011     8         8
# 4099                                 Yuba City, CA   2012    11        11
# 4100                                 Yuba City, CA   2013     7         7
# 4101                                 Yuba City, CA   2014     2         2
# 4102                                 Yuba City, CA   2015     6         6
# 4103                                 Yuba City, CA   2016    13        13
# 4104                                      Yuma, AZ   2006     6         7
# 4105                                      Yuma, AZ   2007    12        13
# 4106                                      Yuma, AZ   2008     6         7
# 4107                                      Yuma, AZ   2009     9        10
# 4108                                      Yuma, AZ   2010     8         9
# 4109                                      Yuma, AZ   2011    13        14
# 4110                                      Yuma, AZ   2012     7         7
# 4111                                      Yuma, AZ   2013    12        12
# 4112                                      Yuma, AZ   2014     8         8
# 4113                                      Yuma, AZ   2015    10        10
#
#       Rate
# 0      3.7
# 1      6.3
# 2      4.4
# 3      4.4
# 4      3.1
# 5      3.0
# 6      1.8
# 7      0.6
# 8      5.9
# 9      5.3
# 10     6.5
# 11     9.3
# 12    11.0
# 13     5.9
# 14     4.8
# 15     7.1
# 16     2.5
# 17     3.9
# 18     6.2
# 19     3.8
# 20     9.8
# 21     3.6
# 22     3.4
# 23     4.0
# 24     3.7
# 25     4.7
# 26     3.8
# 27     5.1
# 28     4.8
# 29     5.1
# ...    ...
# 4084   4.3
# 4085   3.2
# 4086   4.3
# 4087   4.3
# 4088   7.2
# 4089   5.7
# 4090   5.9
# 4091   5.7
# 4092   4.3
# 4093   4.4
# 4094   1.2
# 4095   6.0
# 4096   2.4
# 4097   4.2
# 4098   4.7
# 4099   6.5
# 4100   4.2
# 4101   1.2
# 4102   3.5
# 4103   7.6
# 4104   3.7
# 4105   6.8
# 4106   3.6
# 4107   5.1
# 4108   4.7
# 4109   7.1
# 4110   3.4
# 4111   5.9
# 4112   3.9
# 4113   4.9
#
# [4114 rows x 5 columns]

# %%
df.to_csv('raw data/murder_data.csv')
